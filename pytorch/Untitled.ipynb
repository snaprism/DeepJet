# %%
base_dir = "/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/"
pred_dir = []
text_dir = []
for i in range(11601):
    if i<=2799:
        continue
    if i%100==0:
        pred_dir.append(f"{base_dir}prediction_epoch_0_batch_{i+1}.root")
        text_dir.append(f"{base_dir}outfiles{i+1}.txt")

# %%
pred_dir
# Out:
# ['/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_2801.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_2901.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3001.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3101.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3201.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3301.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3401.root',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/prediction_epoch_0_batch_3501.root',
# ...

# %%
text_dir
# Out:
# ['/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles2801.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles2901.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3001.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3101.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3201.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3301.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3401.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3501.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3601.txt',
#  '/eos/user/a/aljung/DeepJet/Train_DF_Run2/test/batch_checkpoints/predictions/outfiles3701.txt',
# ...
