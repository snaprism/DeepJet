# %% [markdown]
# # ROC curves
# ## Comparison of different trainings with different setups for inference

# %%
import numpy as np

import matplotlib.pyplot as plt
import mplhep as hep


plt.style.use(hep.cms.style.ROOT)

# %%
plt.rcParams['axes.axisbelow'] = True

# %%
'''
#Run3 setup:
model_names = ['nominal_with_etarel_phirel', 'adversarial_with_etarel_phirel']
prediction_setups = ['', '_FGSM']
prediction_files = 'one_prediction'
'''
# Out:
# "\n#Run3 setup:\nmodel_names = ['nominal_with_etarel_phirel', 'adversarial_with_etarel_phirel']\nprediction_setups = ['', '_FGSM']\nprediction_files = 'one_prediction'\n"

# %%
#model_names = ['nominal', 'adversarial_eps0p01', 'adversarial_eps0p005']
model_names = ['nominal', 'adversarial_eps0p01_bsize4000']
#model_names = ['nominal']
prediction_setups = ['', '_fgsm']
#prediction_setups = ['']
prediction_files = 'outfiles'

# %%
tagger = 'DF_Run2' # 'DF'

# %%
dirz = [[f'/eos/home-a/aljung/DeepJet/Train_{tagger}/{model_name}/predict{prediction_setup}/' \
        for model_name in model_names] for prediction_setup in prediction_setups]

# %%
dirz
# Out:
# [['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict/'],
#  ['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_fgsm/'],
#  ['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_pgd/']]

# %%
#dirz[0][0] = '/e'+dirz[0][0].strip('predict/')+'/predict_NEW/'
#dirz[1][0] = '/e'+dirz[1][0].strip('predict_FGSM/')+'/predict_FGSM_NEW/'

# %%
#dirz

# %%
BvsL_paths = [item + f'BvL_{prediction_files}.npy' for sublist in dirz for item in sublist]

# %%
BvsL_paths
# Out:
# ['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict/BvL_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_fgsm/BvL_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_pgd/BvL_outfiles.npy']

# %%
CvsB_paths = [item + f'CvB_{prediction_files}.npy' for sublist in dirz for item in sublist]

# %%
CvsB_paths
# Out:
# ['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict/CvB_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_fgsm/CvB_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_pgd/CvB_outfiles.npy']

# %%
CvsL_paths = [item + f'CvL_{prediction_files}.npy' for sublist in dirz for item in sublist]

# %%
CvsL_paths
# Out:
# ['/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict/CvL_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_fgsm/CvL_outfiles.npy',
#  '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict_pgd/CvL_outfiles.npy']

# %%
#NEW_BvsL_paths = [item + f'BvL_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
#NEW_BvsL_paths

# %%
#NEW_BvsL_paths[1] = NEW_BvsL_paths[1].strip('_NEW.npy')+'.npy'
#NEW_BvsL_paths[3] = NEW_BvsL_paths[3].strip('_NEW.npy')+'.npy'
#NEW_BvsL_paths

# %%
#NEW_CvsB_paths = [item + f'CvB_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
#NEW_CvsB_paths

# %%
#NEW_CvsB_paths[1] = NEW_CvsB_paths[1].strip('_NEW.npy')+'.npy'
#NEW_CvsB_paths[3] = NEW_CvsB_paths[3].strip('_NEW.npy')+'.npy'
#NEW_CvsB_paths

# %%
#NEW_CvsL_paths = [item + f'CvL_{prediction_files}_NEW.npy' for sublist in dirz for item in sublist]

# %%
#NEW_CvsL_paths

# %%
#NEW_CvsL_paths[1] = NEW_CvsL_paths[1].strip('_NEW.npy')+'.npy'
#NEW_CvsL_paths[3] = NEW_CvsL_paths[3].strip('_NEW.npy')+'.npy'
#NEW_CvsL_paths

# %%
xya = np.load(BvsL_paths[0], allow_pickle=True)

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-3)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

linestyles = ['-','-','-','--','--','--']
colors = ['tab:blue','tab:orange','tab:green','tab:blue','tab:orange','tab:green']
names_models = ['Nominal training', r'Adversarial training (against $\epsilon=0.01$)',
                r'Adversarial training (against $\epsilon=0.005$)']
names_setups = ['nominal samples', r'FGSM ($\epsilon=0.01$, limit $20\%$)']
legtitle = 'BvsL'
legloc = 'upper left'
for i in range(len(BvsL_paths)):
    xya = np.load(BvsL_paths[i], allow_pickle=True)
    legend_text = names_models[i % 3] + '\n' + (names_setups[0] if i<3 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title=legtitle,loc=legloc,fontsize=16,title_fontsize=20,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
#hep.cms.text('Simulation Preliminary')
hep.cms.label(rlabel='(13 TeV)')
#hep.cms.rlabel('13 TeV')
#fig.savefig(legtitle + '_' + tagger + '_ROC.pdf', bbox_inches='tight')
plt.show()

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-3)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (c)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

linestyles = ['-','-','-','--','--','--']
colors = ['tab:blue','tab:orange','tab:green','tab:blue','tab:orange','tab:green']
names_models = ['Nominal training', r'Adversarial training (against $\epsilon=0.01$)',
                r'Adversarial training (against $\epsilon=0.005$)']
names_setups = ['nominal samples', r'FGSM ($\epsilon=0.01$, limit $20\%$)']
legtitle = 'BvsC'
legloc = 'upper left'
for i in range(len(BvsC_paths)):
    xya = np.load(BvsC_paths[i], allow_pickle=True)
    legend_text = names_models[i % 3] + '\n' + (names_setups[0] if i<3 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title=legtitle,loc=legloc,fontsize=16,title_fontsize=20,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='(13 TeV)')
#fig.savefig(legtitle + '_' + tagger + '_ROC.pdf', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [35], in <cell line: 24>()
#      23 legloc = 'upper left'
#      24 for i in range(len(BvsC_paths)):
# ---> 25     xya = np.load(BvsC_paths[i], allow_pickle=True)
#      26     legend_text = names_models[i % 3] + '\n' + (names_setups[0] if i<3 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#      27     ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/numpy/lib/npyio.py:407, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     405     own_fid = False
#     406 else:
# --> 407     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     408     own_fid = True
#     410 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/eos/home-a/aljung/DeepJet/Train_DF_Run2/nominal/predict/BvC_outfiles.npy'

# %% [markdown]
# # NEW

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-3)
ax.set_ylim(top=1)

tag_name = ' (b,bb,lepb)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

linestyles = ['-','-','--','--']
colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
names_models = ['nominal training', r'adversarial training, $\epsilon=0.01$']
names_setups = ['nominal inputs', r'adversarial inputs, $\epsilon=0.001$']
legtitle = 'BvsL'
legloc = 'upper left'
for i in range(len(BvsL_paths)):
    #xya = np.load(NEW_BvsL_paths[i], allow_pickle=True)
    xya = np.load(BvsL_paths[i], allow_pickle=True)
    legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='DeepJet '+legtitle,loc=legloc,fontsize=16,title_fontsize=20,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='(13 TeV)')
plt.savefig("/afs/cern.ch/user/a/aljung/work/results/test/bvsl.pdf")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 25>()
#      24 legloc = 'upper left'
#      25 for i in range(len(BvsL_paths)):
#      26     #xya = np.load(NEW_BvsL_paths[i], allow_pickle=True)
# ---> 27     xya = np.load(BvsL_paths[i], allow_pickle=True)
#      28     legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
#      29     ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/numpy/lib/npyio.py:430, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     428         return format.open_memmap(file, mode=mmap_mode)
#     429     else:
# --> 430         return format.read_array(fid, allow_pickle=allow_pickle,
#     431                                  pickle_kwargs=pickle_kwargs)
#     432 else:
#     433     # Try a pickle
#     434     if not allow_pickle:
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/numpy/lib/format.py:747, in read_array(fp, allow_pickle, pickle_kwargs)
#     745     pickle_kwargs = {}
#     746 try:
# --> 747     array = pickle.load(fp, **pickle_kwargs)
#     748 except UnicodeError as err:
#     749     # Friendlier error message
#     750     raise UnicodeError("Unpickling a python object failed: %r\n"
#     751                        "You may need to pass the encoding= option "
#     752                        "to numpy.load" % (err,)) from err
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/__init__.py:48, in <module>
#      45 # let init-time option registration happen
#      46 import pandas.core.config_init
# ---> 48 from pandas.core.api import (
#      49     # dtype
#      50     Int8Dtype,
#      51     Int16Dtype,
#      52     Int32Dtype,
#      53     Int64Dtype,
#      54     UInt8Dtype,
#      55     UInt16Dtype,
#      56     UInt32Dtype,
#      57     UInt64Dtype,
#      58     Float32Dtype,
#      59     Float64Dtype,
#      60     CategoricalDtype,
#      61     PeriodDtype,
#      62     IntervalDtype,
#      63     DatetimeTZDtype,
#      64     StringDtype,
#      65     BooleanDtype,
#      66     # missing
#      67     NA,
#      68     isna,
#      69     isnull,
#      70     notna,
#      71     notnull,
#      72     # indexes
#      73     Index,
#      74     CategoricalIndex,
#      75     RangeIndex,
#      76     MultiIndex,
#      77     IntervalIndex,
#      78     TimedeltaIndex,
#      79     DatetimeIndex,
#      80     PeriodIndex,
#      81     IndexSlice,
#      82     # tseries
#      83     NaT,
#      84     Period,
#      85     period_range,
#      86     Timedelta,
#      87     timedelta_range,
#      88     Timestamp,
#      89     date_range,
#      90     bdate_range,
#      91     Interval,
#      92     interval_range,
#      93     DateOffset,
#      94     # conversion
#      95     to_numeric,
#      96     to_datetime,
#      97     to_timedelta,
#      98     # misc
#      99     Flags,
#     100     Grouper,
#     101     factorize,
#     102     unique,
#     103     value_counts,
#     104     NamedAgg,
#     105     array,
#     106     Categorical,
#     107     set_eng_float_format,
#     108     Series,
#     109     DataFrame,
#     110 )
#     112 from pandas.core.arrays.sparse import SparseDtype
#     114 from pandas.tseries.api import infer_freq
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/api.py:48, in <module>
#      46 from pandas.core.construction import array
#      47 from pandas.core.flags import Flags
# ---> 48 from pandas.core.groupby import (
#      49     Grouper,
#      50     NamedAgg,
#      51 )
#      52 from pandas.core.indexes.api import (
#      53     CategoricalIndex,
#      54     DatetimeIndex,
#    (...)
#      64     UInt64Index,
#      65 )
#      66 from pandas.core.indexes.datetimes import (
#      67     bdate_range,
#      68     date_range,
#      69 )
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/groupby/__init__.py:1, in <module>
# ----> 1 from pandas.core.groupby.generic import (
#       2     DataFrameGroupBy,
#       3     NamedAgg,
#       4     SeriesGroupBy,
#       5 )
#       6 from pandas.core.groupby.groupby import GroupBy
#       7 from pandas.core.groupby.grouper import Grouper
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/groupby/generic.py:70, in <module>
#      68 import pandas.core.common as com
#      69 from pandas.core.construction import create_series_with_explicit_dtype
# ---> 70 from pandas.core.frame import DataFrame
#      71 from pandas.core.generic import NDFrame
#      72 from pandas.core.groupby import base
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/frame.py:157, in <module>
#     151 from pandas.core.arrays.sparse import SparseFrameAccessor
#     152 from pandas.core.construction import (
#     153     extract_array,
#     154     sanitize_array,
#     155     sanitize_masked_array,
#     156 )
# --> 157 from pandas.core.generic import NDFrame
#     158 from pandas.core.indexers import check_key_length
#     159 from pandas.core.indexes.api import (
#     160     DatetimeIndex,
#     161     Index,
#    (...)
#     165     ensure_index_from_sequences,
#     166 )
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/generic.py:114, in <module>
#     105 from pandas.core.dtypes.inference import (
#     106     is_hashable,
#     107     is_nested_list_like,
#     108 )
#     109 from pandas.core.dtypes.missing import (
#     110     isna,
#     111     notna,
#     112 )
# --> 114 from pandas.core import (
#     115     arraylike,
#     116     indexing,
#     117     missing,
#     118     nanops,
#     119 )
#     120 import pandas.core.algorithms as algos
#     121 from pandas.core.array_algos.replace import should_use_regex
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/indexing.py:57, in <module>
#      46 from pandas.core.construction import (
#      47     array as pd_array,
#      48     extract_array,
#      49 )
#      50 from pandas.core.indexers import (
#      51     check_array_indexer,
#      52     is_empty_indexer,
#    (...)
#      55     length_of_indexer,
#      56 )
# ---> 57 from pandas.core.indexes.api import (
#      58     Index,
#      59     MultiIndex,
#      60 )
#      62 if TYPE_CHECKING:
#      63     from pandas import (
#      64         DataFrame,
#      65         Series,
#      66     )
#
# File /eos/home-a/aljung/miniconda3/envs/torch/lib/python3.10/site-packages/pandas/core/indexes/api.py:26, in <module>
#      24 from pandas.core.indexes.category import CategoricalIndex
#      25 from pandas.core.indexes.datetimes import DatetimeIndex
# ---> 26 from pandas.core.indexes.interval import IntervalIndex
#      27 from pandas.core.indexes.multi import MultiIndex
#      28 from pandas.core.indexes.numeric import (
#      29     Float64Index,
#      30     Int64Index,
#      31     NumericIndex,
#      32     UInt64Index,
#      33 )
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:975, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1074, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-3)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (b,bb,lepb)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

linestyles = ['-','-','--','--']
colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
names_models = ['nominal training', r'adversarial training, $\epsilon=0.01$']
names_setups = ['nominal inputs', r'adversarial inputs, $\epsilon=0.001$']
legtitle = 'CvsB'
legloc = 'lower right'
for i in range(len(CvsB_paths)):
    #xya = np.load(NEW_CvsB_paths[i], allow_pickle=True)
    xya = np.load(CvsB_paths[i], allow_pickle=True)
    legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='DeepJet '+legtitle,loc=legloc,fontsize=16,title_fontsize=20,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'left'#'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='(13 TeV)')
plt.savefig("/afs/cern.ch/user/a/aljung/work/results/test/cvsb.pdf")
plt.show()

# %%
fig,ax = plt.subplots(figsize=[12,12])
ax.set_xlim(left=0.,right=1)

ax.set_yscale('log')
ax.set_ylim(bottom=1e-3)
ax.set_ylim(top=1)

tag_name = ' (c)'
mistag_name = ' (uds,g)'

ax.set_ylabel('Mistagging rate'+mistag_name)
ax.set_xlabel('Tagging efficiency'+tag_name)

ax.grid(which='minor', alpha=0.85)
ax.grid(which='major', alpha=0.95, color='black')

linestyles = ['-','-','--','--']
colors = ['tab:blue','tab:orange','tab:blue','tab:orange',]
names_models = ['nominal training', r'adversarial training, $\epsilon=0.01$']
names_setups = ['nominal inputs', r'adversarial inputs, $\epsilon=0.001$']
legtitle = 'CvsL'
legloc = 'lower right'
for i in range(len(CvsL_paths)):
    #xya = np.load(NEW_CvsL_paths[i], allow_pickle=True)
    xya = np.load(CvsL_paths[i], allow_pickle=True)
    legend_text = names_models[i % 2] + '\n' + (names_setups[0] if i<2 else names_setups[1]) + '\n' + 'AUC = ' + f'{xya[2]:.3f}'
    ax.plot(xya[0], xya[1], linestyle=linestyles[i], color=colors[i],linewidth=3.0,label=legend_text)
leg = ax.legend(title='DeepJet '+legtitle,loc=legloc,fontsize=16,title_fontsize=20,labelspacing=0.7,frameon=True,framealpha=1,facecolor='white')
if 'right' in legloc:
    aligned = 'left'#'right'
else:
    aligned = 'left'
leg._legend_box.align = aligned
leg.get_frame().set_linewidth(0.0)
hep.cms.label(rlabel='(13 TeV)')
plt.savefig("/afs/cern.ch/user/a/aljung/work/results/test/cvsl.pdf")
plt.show()
